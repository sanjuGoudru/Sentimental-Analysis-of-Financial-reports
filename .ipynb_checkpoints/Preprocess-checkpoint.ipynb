# %%
import os
import re
import pandas as pd
from nltk.tokenize import RegexpTokenizer, sent_tokenize
import numpy as np

# %%
df = pd.read_excel('cik_list.xlsx')

# %%
df.head(3)
# Out:
#     CIK            CONAME   FYRMO      FDATE     FORM  \
# 0  3662  SUNBEAM CORP/FL/  199803 1998-03-06  10-K405
# 1  3662  SUNBEAM CORP/FL/  199805 1998-05-15     10-Q
# 2  3662  SUNBEAM CORP/FL/  199808 1998-08-13  NT 10-Q
#
#                                    SECFNAME
# 0  edgar/data/3662/0000950170-98-000413.txt
# 1  edgar/data/3662/0000950170-98-001001.txt
# 2  edgar/data/3662/0000950172-98-000783.txt

# %%
f = open('./input_dir/edgar+data+11860+0000011860-00-000019.txt','r', encoding="utf-8")
print(f.readlines())
f.close()
# Out:
# ['-----BEGIN PRIVACY-ENHANCED MESSAGE-----\n', 'Proc-Type: 2001,MIC-CLEAR\n', 'Originator-Name: webmaster@www.sec.gov\n', 'Originator-Key-Asymmetric:\n', ' MFgwCgYEVQgBAQICAf8DSgAwRwJAW2sNKK9AVtBzYZmr6aGjlWyK3XmZv3dTINen\n', ' TWSM7vrzLADbmYQaionwg5sDW3P6oaM5D3tdezXMm7z1T+B+twIDAQAB\n', 'MIC-Info: RSA-MD5,RSA,\n', ' NMffK/FAHfC7nlKKOkDgqIOjFMTUgswdQ++K7GrAtFiO5Gm4j933PjhFE67/O/4M\n', ' NmPkmRWMRZA8+WQL6f+t5g==\n', '\n', '0000011860-00-000019.txt : 20000310\n', '0000011860-00-000019.hdr.sgml : 20000310\n', 'ACCESSION NUMBER:\t\t0000011860-00-000019\n', 'CONFORMED SUBMISSION TYPE:\t10-K\n', 'PUBLIC DOCUMENT COUNT:\t\t14\n', 'CONFORMED PERIOD OF REPORT:\t19991231\n', 'FILED AS OF DATE:\t\t20000309\n', '\n', 'FILER:\n', '\n', '\tCOMPANY DATA:\t\n', '\t\tCOMPANY CONFORMED NAME:\t\t\tBETHLEHEM STEEL CORP /DE/\n', '\t\tCENTRAL INDEX KEY:\t\t\t0000011860\n', '\t\tSTANDARD INDUSTRIAL CLASSIFICATION:\tSTEEL WORKS, BLAST FURNACES  ROLLING MILLS (COKE OVENS) [3312]\n', '\t\tIRS NUMBER:\t\t\t\t240526133\n', '\t\tSTATE OF INCORPORATION:\t\t\tDE\n', '\t\tFISCAL YEAR END:\t\t\t1231\n', '\n', '\tFILING VALUES:\n', '\t\tFORM TYPE:\t\t10-K\n', '\t\tSEC ACT:\t\t\n', '\t\tSEC FILE NUMBER:\t001-01941\n', '\t\tFILM NUMBER:\t\t564550\n', '\n', '\tBUSINESS ADDRESS:\t\n', '\t\tSTREET 1:\t\t1170 EIGHTH AVE\n', '\t\tCITY:\t\t\tBETHLEHEM\n', '\t\tSTATE:\t\t\tPA\n', '\t\tZIP:\t\t\t18016-7699\n', '\t\tBUSINESS PHONE:\t\t6106942424\n', '\n', '\tMAIL ADDRESS:\t\n', '\t\tSTREET 1:\t\t1170 EIGHTH AVE\n', '\t\tCITY:\t\t\tBETHLEHEM\n', '\t\tSTATE:\t\t\tPA\n', '\t\tZIP:\t\t\t18016-7699\n', '\n', '\n', '10-K\n', '1\n', '\n', '\n', '\n', '\n', '\n', '                                                                     1999\n', '\n', '\n', '\n', '                      SECURITIES AND EXCHANGE COMMISSION\n', '                           WASHINGTON, D. C.  20549\n', '\n', '                                 F O R M  10-K\n', '(Mark One)\n', '  x  Annual Report Pursuant to Section 13 or 15(d) of the Securities Exchange\n', ' ---\n', '     of 1934 For the Fiscal Year Ended December 31, 1999\n', '\n', '     Transition Report Pursuant to Section 13 or 15(d) of the Securities\n', ' ---\n', '     Exchange Act of 1934\n', '\n', '                           Commission file number 1-1941\n', '\n', '               B E T H L E H E M   S T E E L   C O R P O R A T I O N\n', '               (Exact name of registrant as specified in its charter)\n', '\n', '                DELAWARE                              24-0526133\n', '        (State of Incorporation)          (I.R.S. Employer Identification No.)\n', '\n', '           1170 Eighth Avenue\n', '         BETHLEHEM, PENNSYLVANIA                       18016-7699\n', '(Address of principal executive offices)               (Zip Code)\n', '\n', "      Registrant's telephone number, including area code:  (610) 694-2424\n", '\n', 'Securities registered pursuant to Section 12(b) of the Act:\n', '\n', '                                                 Name of each exchange on\n', '      Title of each class                            which registered\n', '      -------------------                        ------------------------\n', '\n', 'Common Stock--$1 par value per share              New York Stock Exchange\n', '                                                  Chicago Stock Exchange\n', 'Preference Stock Purchase Rights                  New York Stock Exchange\n', '                                                  Chicago Stock Exchange\n', 'Preferred Stock -- $1 par value per share\n', ' $5.00 Cumulative Convertible                      New York Stock Exchange\n', ' (stated value $50.00 per share)\n', ' $2.50 Cumulative Convertible                      New York Stock Exchange\n', ' (stated value $25.00 per share)\n', '8-3/8% Debentures.  Due March 1, 2001              New York Stock Exchange\n', '8.45% Debentures.  Due March 1, 2005               New York Stock Exchange\n', '\n', '    Securities registered pursuant to Section 12(g) of the Ac ...

# %%
def encode_name(secfname):
    splitted = secfname.split(sep="/")
    name = "+".join(splitted)
    return name

# %% [markdown]
# ## Remove all non-alphanumeric characters except newline and space

# %%
with open('./input_dir/edgar+data+11860+0000011860-00-000019.txt','r', encoding="utf-8") as file:
    lines = file.readlines()
    print(len('\n'.join(lines)))
    for i in range(len(lines)):
        lines[i] = re.sub(r'[^A-Za-z0-9\n\t ]+', ' ', lines[i])
    print(len('\n'.join(lines)))
    for i in range(len(lines)):
        lines[i] = re.sub(r'[^A-Za-z\n\t ]+', ' ', lines[i])
    print(len('\n'.join(lines)))
# Out:
# 1009793
# 976630
# 968035

# %% [markdown]
# ## Removing words with length less than 4

# %%
new_list = [x for x in lines if len(x)>=4]
rem_list = [x for x in lines if len(x)<4]

# %%
len(new_list),len(rem_list)
# Out:
# (15889, 5938)

# %%
lines = new_list

# %% [markdown]
# ## Preprocess

# %%
def preprocess(secfname):
    file_path = './input_dir/'+encode_name(secfname)
    with open(file_path,'r', encoding="utf-8") as file:
        lines = file.readlines()
        ## Remove all non-aphabetic characters except newline character
        for i in range(len(lines)):
            lines[i] = re.sub(r'[^A-Za-z\n ]+', ' ', lines[i])
            lines[i] = re.sub(' +', ' ', lines[i])
        ## Remove lines with length less than 3
        lines = [x for x in lines if len(x)>=3]
        
    write_path = './input_dir/new/'+encode_name(secfname)
    with open(write_path,'w', encoding="utf-8") as w_file:
        w_file.writelines(lines)

# %%
df['SECFNAME'].apply(preprocess)
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 147    None
# 148    None
# 149    None
# 150    None
# 151    None
# Name: SECFNAME, Length: 152, dtype: object

# %%
from bs4 import BeautifulSoup as BS

# %%
with open('./input_dir/new/edgar+data+3662+0000889812-99-003241.txt','r', encoding="utf-8") as file:
    data = file.read()
    soup1 = BS(data)
    soup2 = BS(data,'lxml')
