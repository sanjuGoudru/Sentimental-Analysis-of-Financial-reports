# %%
import pandas as pd

# %%
df = pd.read_csv('LoughranMcDonald_MasterDictionary_2020.csv')

# %%
df.head(3)
# Out:
#         Word  Seq_num  Word Count  Word Proportion  Average Proportion  \
# 0   AARDVARK        1         312     1.422050e-08        1.335201e-08
# 1  AARDVARKS        2           3     1.367356e-10        8.882163e-12
# 2      ABACI        3           9     4.102067e-10        1.200533e-10
#
#         Std Dev  Doc Count  Negative  Positive  Uncertainty  Litigious  \
# 0  3.700747e-06         96         0         0            0          0
# 1  9.362849e-09          1         0         0            0          0
# 2  5.359747e-08          7         0         0            0          0
#
#    Strong_Modal  Weak_Modal  Constraining  Complexity  Syllables     Source
# 0             0           0             0           0          2  12of12inf
# 1             0           0             0           0          2  12of12inf
# 2             0           0             0           0          3  12of12inf

# %%
df.sort_values(by = "Average Proportion",ascending=False)
# Out:
#                Word  Seq_num  Word Count  Word Proportion  Average Proportion  \
# 76946           THE    76950  1528366297         0.069661            0.069944
# 51294            OF    51298  1081033173         0.049272            0.050452
# 2490            AND     2491   828265940         0.037751            0.038203
# 77807            TO    77811   671191739         0.030592            0.029477
# 37323            IN    37327   526525404         0.023998            0.023821
# ...             ...      ...         ...              ...                 ...
# 18689    DECLAIMERS    18690           0         0.000000            0.000000
# 18693  DECLAMATIONS    18694           0         0.000000            0.000000
# 18704     DECLARERS    18705           0         0.000000            0.000000
# 58086   PRESCIENTLY    58090           0         0.000000            0.000000
# 86530       ZYMURGY    86533           0         0.000000            0.000000
#
# ...

# %%
df[df['Word'].isnull()]
# Out:
#       Word  Seq_num  Word Count  Word Proportion  Average Proportion  \
# 50741  NaN    50745      162995         0.000007            0.000004
#
#         Std Dev  Doc Count  Negative  Positive  Uncertainty  Litigious  \
# 50741  0.000032      71816         0         0            0          0
#
#        Strong_Modal  Weak_Modal  Constraining  Complexity  Syllables  \
# 50741             0           0             0           0          1
#
#           Source
# 50741  12of12inf

# %%
df = df.dropna()

# %%
for index, row in df.iterrows():
    if row['Positive'] == row['Negative']:

# %%
pos_df = df[df['Positive']>df['Negative']]

# %%
neg_df = df[df['Positive']<df['Negative']]

# %%
same_df = df[df['Positive']==df['Negative']]

# %%
len(df),len(pos_df),len(neg_df),len(same_df)
# Out:
# (86530, 357, 2352, 83821)

# %%
pos_words = list(pos_df['Word'])

# %%
neg_words = list(neg_df['Word'])

# %%
pos_words_str = '\n'.join(pos_words).lower()
neg_words_str = '\n'.join(neg_words).lower()

# %%
with open('./pos_words.txt','w',encoding="utf-8") as pw_f:
    pw_f.write(pos_words_str)
with open('./neg_words.txt','w',encoding="utf-8") as nw_f:
    nw_f.write(neg_words_str)
